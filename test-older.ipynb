# %%
import xarray as xr

# %%
ds = xr.tutorial.load_dataset("air_temperature")

# %%
ds.to_zarr("data/air_temperature", mode="w")
# Out:
# /var/folders/70/hc_nynms54d8lp67z4rsfctc0000gp/T/ipykernel_75149/910278112.py:1: SerializationWarning: saving variable None with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds.to_zarr("data/air_temperature", mode="w")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/test-older-xarray/lib/python3.12/site-packages/zarr/core/common.py:139, in parse_shapelike(data)
#     138 try:
# --> 139     data_tuple = tuple(data)
#     140 except TypeError as e:
#
# TypeError: 'NoneType' object is not iterable
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds.to_zarr("data/air_temperature", mode="w")
#
# ...
